# %%
import pandas as pd
from sqlalchemy import create_engine
from config import pwd
import psycopg2

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "Resources/allpovu.csv"
data_df = pd.read_csv(csv_file)
data_df.head()
# Out:
#            Table with column headers in rows 3 and 4        Unnamed: 1  \
# 0  Table:  Estimated Population in Poverty Univer...               NaN
# 1                                                NaN               NaN
# 2                                    State FIPS code  County FIPS code
# 3                                                  0                 0
# 4                                                  1                 0
#
#       Unnamed: 2         Unnamed: 3  \
# 0            NaN                NaN
# 1            NaN                NaN
# 2           Name  State Postal Code
# 3  United States                 US
# 4        Alabama                 AL
#
#                                           Unnamed: 4  \
# 0                                                NaN
# 1  July 2017 ACS-Like Poverty Universe for 2017 E...
# 2                         Poverty Universe, All Ages
# 3                                        317,741,588
# ...

# %% [markdown]
# ### Create new data with select columns

# %%
new_header = data_df.iloc[2] #grab the first row for the header
data_df.columns = new_header
data_df.head()
# Out:
# 2                                    State FIPS code  County FIPS code  \
# 0  Table:  Estimated Population in Poverty Univer...               NaN
# 1                                                NaN               NaN
# 2                                    State FIPS code  County FIPS code
# 3                                                  0                 0
# 4                                                  1                 0
#
# 2           Name  State Postal Code  \
# 0            NaN                NaN
# 1            NaN                NaN
# 2           Name  State Postal Code
# 3  United States                 US
# 4        Alabama                 AL
#
# 2                         Poverty Universe, All Ages  \
# 0                                                NaN
# 1  July 2017 ACS-Like Poverty Universe for 2017 E...
# 2                         Poverty Universe, All Ages
# 3                                        317,741,588
# ...

# %%
poverty_data_df = data_df[4:]
poverty_data_df
# Out:
# 2    State FIPS code County FIPS code               Name State Postal Code  \
# 4                  1                0            Alabama                AL
# 5                  1                1     Autauga County                AL
# 6                  1                3     Baldwin County                AL
# 7                  1                5     Barbour County                AL
# 8                  1                7        Bibb County                AL
# ...              ...              ...                ...               ...
# 3199              56               37  Sweetwater County                WY
# 3200              56               39       Teton County                WY
# 3201              56               41       Uinta County                WY
# 3202              56               43    Washakie County                WY
# 3203              56               45      Weston County                WY
#
# ...

# %%
poverty_data_df = poverty_data_df.iloc[:, 0:8] # first seven columns of data frame with all rows
poverty_data_df
# Out:
# 2    State FIPS code County FIPS code               Name State Postal Code  \
# 4                  1                0            Alabama                AL
# 5                  1                1     Autauga County                AL
# 6                  1                3     Baldwin County                AL
# 7                  1                5     Barbour County                AL
# 8                  1                7        Bibb County                AL
# ...              ...              ...                ...               ...
# 3199              56               37  Sweetwater County                WY
# 3200              56               39       Teton County                WY
# 3201              56               41       Uinta County                WY
# 3202              56               43    Washakie County                WY
# 3203              56               45      Weston County                WY
#
# ...

# %%
poverty_data_df
# Out:
# 2    State FIPS code County FIPS code               Name State Postal Code  \
# 4                  1                0            Alabama                AL
# 5                  1                1     Autauga County                AL
# 6                  1                3     Baldwin County                AL
# 7                  1                5     Barbour County                AL
# 8                  1                7        Bibb County                AL
# ...              ...              ...                ...               ...
# 3199              56               37  Sweetwater County                WY
# 3200              56               39       Teton County                WY
# 3201              56               41       Uinta County                WY
# 3202              56               43    Washakie County                WY
# 3203              56               45      Weston County                WY
#
# ...

# %%
poverty_df = poverty_data_df[['State FIPS code', 'County FIPS code', 'Name','State Postal Code','Poverty Universe, All Ages']].copy()
poverty_df = poverty_df.loc[poverty_df['County FIPS code'] != '0']
poverty_df.head()
# Out:
# 2 State FIPS code County FIPS code            Name State Postal Code  \
# 5               1                1  Autauga County                AL
# 6               1                3  Baldwin County                AL
# 7               1                5  Barbour County                AL
# 8               1                7     Bibb County                AL
# 9               1                9   Blount County                AL
#
# 2 Poverty Universe, All Ages
# 5                     55,021
# 6                    209,922
# 7                     22,224
# 8                     20,434
# 9                     57,452

# %%
def remove_county(county):
    return county.split(" ")[0]

poverty_df['Name'] = poverty_df['Name'].apply(remove_county)
poverty_df.head()
# Out:
# 2 State FIPS code County FIPS code     Name State Postal Code  \
# 5               1                1  Autauga                AL
# 6               1                3  Baldwin                AL
# 7               1                5  Barbour                AL
# 8               1                7     Bibb                AL
# 9               1                9   Blount                AL
#
# 2 Poverty Universe, All Ages
# 5                     55,021
# 6                    209,922
# 7                     22,224
# 8                     20,434
# 9                     57,452

# %%
poverty_df = poverty_df.reset_index()
poverty_df.head()
# Out:
# 2  index State FIPS code County FIPS code     Name State Postal Code  \
# 0      5               1                1  Autauga                AL
# 1      6               1                3  Baldwin                AL
# 2      7               1                5  Barbour                AL
# 3      8               1                7     Bibb                AL
# 4      9               1                9   Blount                AL
#
# 2 Poverty Universe, All Ages
# 0                     55,021
# 1                    209,922
# 2                     22,224
# 3                     20,434
# 4                     57,452

# %%
poverty_df = poverty_df[['State FIPS code', 'County FIPS code', 'Name', 'State Postal Code', 'Poverty Universe, All Ages']]
poverty_df.head()
# Out:
# 2 State FIPS code County FIPS code     Name State Postal Code  \
# 0               1                1  Autauga                AL
# 1               1                3  Baldwin                AL
# 2               1                5  Barbour                AL
# 3               1                7     Bibb                AL
# 4               1                9   Blount                AL
#
# 2 Poverty Universe, All Ages
# 0                     55,021
# 1                    209,922
# 2                     22,224
# 3                     20,434
# 4                     57,452

# %%
poverty_df.columns = ['State FIPS code', 'County FIPS code', 'Name', 'State Postal Code', 'Poverty Universe, All Ages']
poverty_df = poverty_df.rename(columns={"State FIPS code": "state_fips_code",
                                                         "County FIPS code": "county_fips_code",
                                                         "Name": "name_county",
                                                         "State Postal Code": "state_abbr",
                                                          "Poverty Universe, All Ages": "poverty_population" })


poverty_df.head()
# Out:
#   state_fips_code county_fips_code name_county state_abbr poverty_population
# 0               1                1     Autauga         AL             55,021
# 1               1                3     Baldwin         AL            209,922
# 2               1                5     Barbour         AL             22,224
# 3               1                7        Bibb         AL             20,434
# 4               1                9      Blount         AL             57,452

# %%
poverty_df['poverty_population'] = poverty_df['poverty_population'].astype(str).str.replace(',', '')
poverty_df.count()
# Out:
# state_fips_code       3149
# county_fips_code      3149
# name_county           3149
# state_abbr            3149
# poverty_population    3149
# dtype: int64

# %%
#poverty_df.dropna(inplace=True)
#povert

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = f"postgres:{pwd}@localhost:5432/ETL"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['poverty', 'co_income']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
poverty_df.to_sql(name='poverty', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the poverty table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from poverty', con=engine).head()
# Out:
#    id  state_fips_code  county_fips_code name_county state_abbr  \
# 0   1                1                 1     Autauga         AL
# 1   2                1                 3     Baldwin         AL
# 2   3                1                 5     Barbour         AL
# 3   4                1                 7        Bibb         AL
# 4   5                1                 9      Blount         AL
#
#   poverty_population
# 0              55021
# 1             209922
# 2              22224
# 3              20434
# 4              57452
